# %% [markdown]
# <a href="https://colab.research.google.com/github/regalleo/regalleo/blob/main/python_filei/o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import re
import csv

# %%
# #LEARNINGS:
# with open("filename.txt", "r") as f:
#     data = f.read()
# # File auto closes here

# Modes:
# "r" → read (default)
# "w" → write (overwrites)
# "a" → append
# "r+" → read/write

# 🔥 Step 2:Reading from Files
# # Read entire content
# with open("sample.txt", "r") as f:
#     content = f.read()
# print(content)

# # Read line by line
# with open("sample.txt", "r") as f:
#     for line in f:
#         print(line.strip())   # strip() removes \n and spaces

# # Read into list
# with open("sample.txt", "r") as f:
#     lines = f.readlines()
# print(lines)   # list of lines

# 🔥 Step 3: Writing to Files
# # Overwrite
# with open("sample.txt", "w") as f:
#     f.write("First line\n")
#     f.write("Second line")

# # Append
# with open("sample.txt", "a") as f:
#     f.write("\nAppended line")

# 🔥 Step 4: CSV Files (Structured Data)

# Python has a csv module.

# Writing CSV
# import csv

# rows = [
#     ["ID", "Name", "Marks"],
#     [1, "Alice", 87],
#     [2, "Bob", 76],
# ]

# with open("students.csv", "w", newline="") as f:
#     writer = csv.writer(f)
#     writer.writerows(rows)

# Reading CSV
# import csv

# with open("students.csv", "r") as f:
#     reader = csv.reader(f)
#     for row in reader:
#         print(row)

# 🔥 Step 5: Cleaning & Processing Data

# 👉 Real files are messy. You must clean → transform → output.

# Extra Spaces
# line = "   Alice    Wonderland   "
# clean = " ".join(line.split())
# print(clean)  # "Alice Wonderland"

# Remove Special Characters
# import re
# line = "Charlie@@Chaplin"
# clean = re.sub(r'[^a-zA-Z ]', '', line)
# print(clean)  # "Charlie Chaplin"

# Missing/Invalid Numbers
# cgpa = "??"
# if not cgpa.replace(".", "", 1).isdigit():  #NOTE: .replace(old,new,count): here count:how many times to replace
#     cgpa = "0"
# print(cgpa)

# %%
# 🔥 Step 6: Golden 5-Minute Problem-Solving Formula
# 1.Whenever you see a file handling question:

# 2.Open file (with open() as f)

# 3.Read data (read(), readlines(), or csv.reader)

# 4.Clean data (strip(), split(), re.sub(), isdigit())

# 5.Transform (split names, abbreviate branches, format ID, etc.)

# 6.Write back to new file (write(), writelines(), csv.writer)

# %%
#GREAT EXAMPLE OF CLEANING THE DATA:
# import re

# cleaned_lines = []
# for line in lines:
#     parts = [p.strip() for p in line.split(",")]

#     # Unpack parts
#     student_id, name, branch, sem, cgpa = parts

#     # 1. Format StudentID → S-001
#     student_id = "S-" + student_id[1:].zfill(3)

#     # 2. Clean Name → remove multiple spaces + special characters
#     name = " ".join(name.split())   # collapse extra spaces
#     name = re.sub(r"[^a-zA-Z ]", "", name)  # remove non-letters

#     # 3. Abbreviate Branch
#     branch_map = {
#         "Computer Science": "CS",
#         "Mechanical Engineering": "ME",
#         "Electrical Engineering": "EE",
#         "Civil Engineering": "CE",
#         "Information Technology": "IT",
#         "Electronics": "EC"
#     }
#     branch = branch_map.get(branch, "OTH")

#     # 4. Fix Semester
#     if not sem.isdigit():
#         sem = "0"

#     # 5. Fix CGPA
#     if not cgpa.replace(".", "", 1).isdigit():
#         cgpa = "0"

#     # Rebuild cleaned line
#     cleaned_line = f"{student_id}, {name}, {branch}, {sem}, {cgpa}"
#     cleaned_lines.append(cleaned_line)

# print("\n✅ Cleaned lines:")
# for cl in cleaned_lines:
#     print(cl)

# %%
#SAMPLE QUESTION 1:
# import re
# fs = open("text.txt","r")
# fd = open("text2.txt","w")
# lines = fs.readlines()
# header = lines[0].strip()+",Tax\n"
# fd.write(header)
# for i in lines[1:]:
#     parts = i.strip().split(",")
#     #emp ID
#     parts[0] = re.sub(r"[@#]+","-",parts[0])
#     #name
#     if parts[1] == "":
#         parts[1] = "unknown"
#     #salary
#     try:
#         salary = float(parts[3])
#     except ValueError:
#         salary = 0.0
#     salary = round(salary)
#     parts[3]=str(salary)
#     #email
#     parts[4] = parts[4].replace("@@","@")
#     if not parts[4].endswith(".com"):
#         parts[4]+=".com"
#     if(salary>=80000):
#         parts.append("High")
#     elif(50000<=salary<80000):
#         parts.append("Medium")
#     else:
#         parts.append("Low")

#     new_line = ",".join(parts)
#     fd.write(new_line+"\n")
# fs.close()
# fd.close()

# Q2. Student Grade Processing
# 📂 File: students.tx
# Columns: ID, Name, Marks, Department
# Tasks:
# Clean ID (remove spaces/symbols).
# If Name empty → "Unknown".
# Convert Marks → integer (if invalid → 0).
# Add a new column Grade:
# A if marks ≥ 85
# B if 70–84
# C if 50–69
# F if < 50
# Save cleaned data to students_cleaned.txt.
import re
with open("student_data_txt.txt","r") as f:
  lines=f.readlines()
  header=lines[0].strip()+",Grade\n"
  for i in lines[1:]:
    parts=i.strip().split(",")
    #clean_id
    parts[0]=re.sub(r'[^a-zA-Z0-9]',"",parts[0].strip())
    #clean_name
    if(parts[1]==""):
      parts[1]="unknown"
    #clean_marks
    try:
      marks=int(parts[2])
    except ValueError:
      marks=0
    parts[2]=str(marks)
    #clean_dept
    parts[3]=parts[3].strip()
    #clean_grade
    if(marks>=85):
      parts.append("A")
    elif(70<=marks<=84):
      parts.append("B")
    elif(50<=marks<=69):
      parts.append("C")
    else:
      parts.append("F")
    new_line=",".join(parts)
with open("student_cleaned.txt","w") as f1:
  f1.write(new_line+"\n")



# Q3. Book Store Sales Normalization

# 📂 File: books.txt

# Columns: BookID, Title, Author, Price, Copies

# Tasks:

# Fix BookID (B001 format).

# Remove extra spaces/special chars in Title.

# Ensure Price is float, round to 2 decimals.

# Ensure Copies is integer (default 0).

# Add new column TotalSales = Price * Copies.

# Write to books_cleaned.txt.

# Q4. Hospital Patient Data Cleaning

# 📂 File: patients.txt

# Columns: PatientID, Name, Age, Disease, Bill

# Tasks:

# Format PatientID as P-000X.

# Replace missing Name with "Anonymous".

# Ensure Age is integer (default 0).

# Remove digits from Disease field (only letters allowed).

# Add Category: "Senior" if Age ≥ 60 else "Adult".

# Save to patients_cleaned.txt.

# Q5. Movie Ratings Transformation

# 📂 File: movies.txt

# Columns: MovieID, Title, Genre, Rating, Year

# Tasks:

# Format MovieID → M-XXX.

# Ensure Rating is float (default 0.0).

# If Year < 2000 → add Category "Classic", else "Modern".

# Ensure Genre abbreviations: Action→ACT, Drama→DRM, Comedy→COM.

# Save to movies_cleaned.txt.

# Q6. Product Catalog Cleanup

# 📂 File: products.txt

# Columns: ProdID, Name, Category, Price, Discount%

# Tasks:

# Format ProdID → PRD-XXX.

# Ensure Price is float (default 0.0).

# Ensure Discount% is integer (default 0).

# Add column FinalPrice = Price - (Price * Discount/100).

# Save to products_cleaned.txt.

# Q7. Library Member Database

# 📂 File: members.txt

# Columns: MemberID, Name, Age, Email, BooksIssued

# Tasks:

# Fix MemberID format → MBR-XXX.

# If Email missing → "not_provided@email.com".

# Age must be integer (default 0).

# If BooksIssued > 5 → add "VIP" else "Normal".

# Save to members_cleaned.txt.

# Q8. Transport Bus Records

# 📂 File: buses.txt

# Columns: BusID, DriverName, Route, Capacity, Occupied

# Tasks:

# Format BusID → BUS-XXX.

# Ensure Capacity/Occupied are integers (default 0).

# Calculate VacantSeats = Capacity - Occupied.

# If VacantSeats < 0 → make 0.

# Save to buses_cleaned.txt.

# Q9. Online Orders Management

# 📂 File: orders.txt

# Columns: OrderID, CustomerName, Item, Price, Quantity

# Tasks:

# Format OrderID → ORD-XXX.

# Clean CustomerName (no digits/special chars).

# Ensure Price is float, Quantity is int.

# Add new column TotalAmount = Price * Quantity.

# Save to orders_cleaned.txt.

# Q10. Exam Results Categorization

# 📂 File: results.txt

# Columns: RollNo, Name, Subject, Marks

# Tasks:

# Format RollNo → R-XXXX.

# If Name empty → "Unknown".

# Marks must be int (default 0).

# Add Result = Pass if Marks ≥ 40 else Fail.

# Save to results_cleaned.txt.
